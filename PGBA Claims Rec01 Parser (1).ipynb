# %%
# %sql
/***********************************************/
/*          Drop & Recreate data table         */
/***********************************************/
Drop Table if exists claims_raw_R01;	
CREATE TABLE claims_raw_R01 (
VHDR_SBSCR_ID_NO  string,
VHDR_PLAN_CODE_NO  string,
VHDR_PAT_ID  string,
VHDR_CLAIM_NUMBER  string,
VHDR_CLAIM_NO  string,
VHDR_SUBCLAIM_NO  string,
VHDR_CMPL_ADJ_NO  string,
VHDR_REC_TYPE  string,
VHDR_LINE_NO  string,
VHDR_SBSCR_NAME  string,
VHDR_SBSCR_TITLE  string,
VHDR_SBSCR_FIRST_NAME  string,
VHDR_SBSCR_MID_INIT  string,
VHDR_SBSCR_LAST_NAME  string,
VHDR_SBSCR_GEN  string,
VHDR_PAT_NAME  string,
VHDR_PAT_FIRST_NAME  string,
VHDR_PAT_MID_INIT  string,
VHDR_PAT_LAST_NAME  string,
VHDR_PAT_GENERATION  string,
VHDR_PAT_ADDRESS_1  string,
VHDR_PAT_ADDRESS_2  string,
VHDR_PAT_CITY  string,
VHDR_ST_CODE  string,
VHDR_ZIP_CODE  string,
VHDR_ALT_PAT_ID  string,
VHDR_SEX_RELSHP_CODE  string,
VHDR_PAT_DATE_OF_BIRTH  string,
VHDR_PAT_ZIP_CD_X  string,
VHDR_PAT_ZIP_CD_5  string,
VHDR_PAT_ZIP_CD_4  string,
VHDR_PAT_ZIP_CODE  string,
VHDR_PAT_COV_EFF_DATE  string,
VHDR_PAT_COV_TO_DATE  string,
VHDR_GRP_NO_CUR  string,
VHDR_CONTRACT_KEY_CUR  string,
VHDR_MSTR_GRP_NO_CUR  string,
VHDR_NBR_LINES  string,
VHDR_SPLIT_CLAIM  string,
VHDR_MED_REC_NO  string,
VHDR_PAT_CNTL_NO  string,
VHDR_PRIM_DIAG_X  string,
VHDR_PRIM_DIAG_1  string,
VHDR_PRIM_DIAG_2  string,
VHDR_PRIM_DIAG_3  string,
VHDR_PRIM_DIAG_4  string,
VHDR_PRIM_DIAG_5  string,
VHDR_PRIM_DIAG_6  string,
VHDR_PRIM_DIAG_7  string,
VHDR_PRIM_DIAG_8  string,
VHDR_PRIM_DIAG_9  string,
VHDR_PRIM_DIAG_10  string,
VHDR_FROM_DATE_SRVC  string,
VHDR_TO_DATE_SRVC  string,
VHDR_CLAIM_RECV_DATE  string,
VHDR_DATE_CLAIM_ENTER  string,
VHDR_STLMT_CUTOFF_DTE  string,
VHDR_TOT_CHRG_AMT  string,
VHDR_TOT_CHRG_NON_COV  string,
VHDR_ALLOW_AMT  string,
VHDR_REG_DED_TAKEN  string,
VHDR_SPEC_DED_TAKEN  string,
VHDR_DED_COINS_AMT  string,
VHDR_CLM_PAY_AMT  string,
VHDR_CLAIM_AMT_PAID_BENE  string,
VHDR_AMT_PAID_BY_SBSCR  string,
VHDR_CLAIM_AMT_PAID_PVDR  string,
VHDR_PAT_LIAB_AMT  string,
VHDR_CLM_INTRST_AMT  string,
VHDR_PATIENT_RESP_AMT  string,
VHDR_CLAIM_TRANS_CODE  string,
VHDR_CLAIM_SOURCE_CODE  string,
VHDR_CLAIM_PYMT_INDC  string,
VHDR_CLM_FORM_CD  string,
VHDR_OCL_COB_IND  string,
VHDR_EOB_MSG_CODE  string,
VHDR_TPR_INDC  string,
VHDR_DENTAL_COV_INDC  string,
VHDR_IMAGE_NO  string,
VHDR_PAT_DISP  string,
VHDR_INST_PROF_FLAG  string,
VHDR_EMERGENCY_INDC  string,
VHDR_OOP_MET_INDC  string,
VHDR_CATCHMENT_INDC  string,
VHDR_CLM_ORIG_INDC  string,
VHDR_EOB_SPCL_HNDL_CD  string,
VHDR_EOB_MEDIA_DEST  string,
VHDR_BP_START_DATE  string,
VHDR_NO_PYMT_RED_DAY_SRVC  string,
VHDR_MAX_REDUCT_AMT  string,
VHDR_OTH_CARR_AMT_MAJ_MED  string,
VHDR_TOTAL_OOP_EXP  string,
VHDR_TOT_BP_DAYS_COST_SHR  string,
VHDR_COST_SHARE_MET_AMT  string,
VHDR_INDV_OOP_MET_AMT  string,
VHDR_MEDICAID_PAID_AMT  string,
VHDR_OTHR_HLTH_INS_ALOW_AMT  string,
VHDR_RED_PYMT_RED  string,
VHDR_PYMT_RED_AMT  string,
VHDR_TPL_AMT  string,
VHDR_ADJ_REAS  string,
VHDR_DATE_ADJ_ID  string,
VHDR_DEBIT_CRD_INDC  string,
VHDR_RFND_CNTL_NO  string,
VHDR_ALPHA_SUFFIX  string,
VHDR_EMC_TPR_OHI_ZERO_INDC  string,
VHDR_EMC_CLAIM_TYPE  string,
VHDR_EMC_SBMTD_ID  string,
VHDR_EMC_VNDR  string,
VHDR_CLAIM_STATUS  string,
VHDR_CURR_STAT_DATE  string,
VHDR_PRCSNG_TIME  string,
VHDR_DEFER_OVERRIDE_X  string,
VHDR_DEFER_OVERRIDE_1  string,
VHDR_DEFER_OVERRIDE_2  string,
VHDR_DEFER_OVERRIDE_3  string,
VHDR_PRIMARY_STATUS  string,
VHDR_STATUS_SECT_X  string,
VHDR_STAT_OVERRIDE_INDC_1  string,
VHDR_STAT_CODE_1  string,
VHDR_STAT_OVERRIDE_INDC_2  string,
VHDR_STAT_CODE_2  string,
VHDR_STAT_OVERRIDE_INDC_3  string,
VHDR_STAT_CODE_3  string,
VHDR_STAT_OVERRIDE_INDC_4  string,
VHDR_STAT_CODE_4  string,
VHDR_STAT_OVERRIDE_INDC_5  string,
VHDR_STAT_CODE_5  string,
VHDR_STAT_OVERRIDE_INDC_6  string,
VHDR_STAT_CODE_6  string,
VHDR_STAT_OVERRIDE_INDC_7  string,
VHDR_STAT_CODE_7  string,
VHDR_STAT_OVERRIDE_INDC_8  string,
VHDR_STAT_CODE_8  string,
VHDR_STAT_OVERRIDE_INDC_9  string,
VHDR_STAT_CODE_9  string,
VHDR_STAT_OVERRIDE_INDC_10  string,
VHDR_STAT_CODE_10  string,
VHDR_PROCR_CODE  string,
VHDR_RACF_ENTRY_EMP  string,
VHDR_RACF_PROC_EMP  string,
VHDR_SENIOR_PRIME_CLEAN_IND  string,
VHDR_RETAIN_EXCLUDE_INDC  string,
VHDR_POTENT_INTRST_INDC  string,
VHDR_CLEAN_INDC_PRTY  string,
VHDR_INTRST_LIAB_INDC  string,
VHDR_DELAY_RPT_GRP_INDC  string,
VHDR_PAYEE_SECT  string,
VHDR_PAYEE_FIRST_NAME  string,
VHDR_PAYEE_MID_INIT  string,
VHDR_PAYEE_LAST_NAME  string,
VHDR_PAYEE_GENERATION  string,
VHDR_SUB_ADDR_LINE1  string,
VHDR_SUB_ADDR_LINE2  string,
VHDR_SUB_PAT_CITY  string,
VHDR_SUB_ST_CODE  string,
VHDR_SUB_ZIP_CODE  string,
VHDR_ADM_DATE  string,
VHDR_DISCHARGE_DATE  string,
VHDR_BILL_STAT  string,
VHDR_SUCSV_ADM_INDC  string,
VHDR_INIT_ADM_DATE  string,
VHDR_ADM_DIAG_CODE  string,
VHDR_DISCHRG_STAT  string,
VHDR_DRG_TYPE_PRICING_METH  string,
VHDR_DIAG_REL_GRP  string,
VHDR_FY_INDC_1  string,
VHDR_FY_FAM_DED_TO_DA_1  string,
VHDR_FY_PAT_DED_TO_DA_1  string,
VHDR_FY_DED_AMT_1  string,
VHDR_FY_INDC_2  string,
VHDR_FY_FAM_DED_TO_DA_2  string,
VHDR_FY_PAT_DED_TO_DA_2  string,
VHDR_FY_DED_AMT_2  string,
VHDR_FY_INDC_3  string,
VHDR_FY_FAM_DED_TO_DA_3  string,
VHDR_FY_PAT_DED_TO_DA_3  string,
VHDR_FY_DED_AMT_3  string,
VHDR_FY_INDC_4  string,
VHDR_FY_FAM_DED_TO_DA_4  string,
VHDR_FY_PAT_DED_TO_DA_4  string,
VHDR_FY_DED_AMT_4  string,
VHDR_FY_INDC_5  string,
VHDR_FY_FAM_DED_TO_DA_5  string,
VHDR_FY_PAT_DED_TO_DA_5  string,
VHDR_FY_DED_AMT_5  string,
VHDR_FY_INDC_6  string,
VHDR_FY_FAM_DED_TO_DA_6  string,
VHDR_FY_PAT_DED_TO_DA_6  string,
VHDR_FY_DED_AMT_6  string,
VHDR_COST_FY_INDC_1  string,
VHDR_COST_BP_DAYS_COST_SHR_1  string,
VHDR_COST_BP_COST_SHR_MET_1  string,
VHDR_COST_FY_INDC_2  string,
VHDR_COST_BP_DAYS_COST_SHR_2  string,
VHDR_COST_BP_COST_SHR_MET_2  string,
VHDR_SNF_PROCS_CD  string,
VHDR_AMT_PAID_MEDICARE  string,
VHDR_OHI_SUS_INDC  string,
VHDR_MBR_HIC_NO  string,
VHDR_PAT_REL_CODE  string,
VHDR_DATE_RESP_RECV  string,
VHDR_ELIG_DOC_ATCH_INDC  string,
VHDR_REMK_CODE  string,
VHDR_PLN_COV_OPT_CD  string,
VHDR_PRICING_TYP  string,
VHDR_PRIC_METH  string,
VHDR_HIPAA_PRIV_INDC  string,
VHDR_HIPAA_CLM_INDC  string,
VHDR_FOREIGN_CURRENCY_CD  string,
VHDR_DISCP_TYP_CD_X  string,
VHDR_DISCP_TYP_CD_1  string,
VHDR_DISCP_TYP_CD_2  string,
VHDR_DISCP_TYP_CD_3  string,
VHDR_DISCP_TYP_CD_4  string,
VHDR_DISCP_TYP_CD_5  string,
VHDR_DISCP_TYP_CD_6  string,
VHDR_PRIOR_CLM_ADJ_DTE_X  string,
VHDR_PRIOR_CLM_ADJ_DTE_1  string,
VHDR_PRIOR_CLM_ADJ_DTE_2  string,
VHDR_PRIOR_CLM_ADJ_DTE_3  string,
VHDR_MSN_CD_GRP_1  string,
VHDR_MSN_CD_REAS_1_1  string,
VHDR_MSN_CD_REAS_1_2  string,
VHDR_MSN_CD_REAS_1_3  string,
VHDR_MSN_CD_REAS_1_4  string,
VHDR_MSN_CD_REAS_1_5  string,
VHDR_MSN_CD_REAS_1_6  string,
VHDR_MSN_CD_AMT_1_1  string,
VHDR_MSN_CD_AMT_1_2  string,
VHDR_MSN_CD_AMT_1_3  string,
VHDR_MSN_CD_AMT_1_4  string,
VHDR_MSN_CD_AMT_1_5  string,
VHDR_MSN_CD_AMT_1_6  string,
VHDR_MSN_CD_GRP_2  string,
VHDR_MSN_CD_REAS_2_1  string,
VHDR_MSN_CD_REAS_2_2  string,
VHDR_MSN_CD_REAS_2_3  string,
VHDR_MSN_CD_REAS_2_4  string,
VHDR_MSN_CD_REAS_2_5  string,
VHDR_MSN_CD_REAS_2_6  string,
VHDR_MSN_CD_AMT_2_1  string,
VHDR_MSN_CD_AMT_2_2  string,
VHDR_MSN_CD_AMT_2_3  string,
VHDR_MSN_CD_AMT_2_4  string,
VHDR_MSN_CD_AMT_2_5  string,
VHDR_MSN_CD_AMT_2_6  string,
VHDR_MSN_CD_GRP_3  string,
VHDR_MSN_CD_REAS_3_1  string,
VHDR_MSN_CD_REAS_3_2  string,
VHDR_MSN_CD_REAS_3_3  string,
VHDR_MSN_CD_REAS_3_4  string,
VHDR_MSN_CD_REAS_3_5  string,
VHDR_MSN_CD_REAS_3_6  string,
VHDR_MSN_CD_AMT_3_1  string,
VHDR_MSN_CD_AMT_3_2  string,
VHDR_MSN_CD_AMT_3_3  string,
VHDR_MSN_CD_AMT_3_4  string,
VHDR_MSN_CD_AMT_3_5  string,
VHDR_MSN_CD_AMT_3_6  string,
VHDR_MSN_CD_GRP_4  string,
VHDR_MSN_CD_REAS_4_1  string,
VHDR_MSN_CD_REAS_4_2  string,
VHDR_MSN_CD_REAS_4_3  string,
VHDR_MSN_CD_REAS_4_4  string,
VHDR_MSN_CD_REAS_4_5  string,
VHDR_MSN_CD_REAS_4_6  string,
VHDR_MSN_CD_AMT_4_1  string,
VHDR_MSN_CD_AMT_4_2  string,
VHDR_MSN_CD_AMT_4_3  string,
VHDR_MSN_CD_AMT_4_4  string,
VHDR_MSN_CD_AMT_4_5  string,
VHDR_MSN_CD_AMT_4_6  string,
VHDR_MSN_CD_GRP_5  string,
VHDR_MSN_CD_REAS_5_1  string,
VHDR_MSN_CD_REAS_5_2  string,
VHDR_MSN_CD_REAS_5_3  string,
VHDR_MSN_CD_REAS_5_4  string,
VHDR_MSN_CD_REAS_5_5  string,
VHDR_MSN_CD_REAS_5_6  string,
VHDR_MSN_CD_AMT_5_1  string,
VHDR_MSN_CD_AMT_5_2  string,
VHDR_MSN_CD_AMT_5_3  string,
VHDR_MSN_CD_AMT_5_4  string,
VHDR_MSN_CD_AMT_5_5  string,
VHDR_MSN_CD_AMT_5_6  string,
VHDR_MSN_CD_GRP_6  string,
VHDR_MSN_CD_REAS_6_1  string,
VHDR_MSN_CD_REAS_6_2  string,
VHDR_MSN_CD_REAS_6_3  string,
VHDR_MSN_CD_REAS_6_4  string,
VHDR_MSN_CD_REAS_6_5  string,
VHDR_MSN_CD_REAS_6_6  string,
VHDR_MSN_CD_AMT_6_1  string,
VHDR_MSN_CD_AMT_6_2  string,
VHDR_MSN_CD_AMT_6_3  string,
VHDR_MSN_CD_AMT_6_4  string,
VHDR_MSN_CD_AMT_6_5  string,
VHDR_MSN_CD_AMT_6_6  string,
VHDR_ORIG_CLAIM_NUMBER  string,
VHDR_ORIG_CLAIM_NO  string,
VHDR_ORIG_SUBCLAIM_NO  string,
VHDR_ORIG_CMPL_ADJ_NO  string,
VHDR_BTCH_VCHR_NO  string,
VHDR_HHA_PROCS_CD  string,
VHDR_ICN_DCN  string,
VHDR_LEGAL_AUTH_CD  string,
VHDR_ORIG_PLAN_CD  string,
VHDR_TRANSF_DTE  string,
VHDR_HHS_PPS_CLAIM_DATA  string,
VHDR_PEP_INDC  string,
VHDR_PEP_DAYS  string,
VHDR_RVNU_SUM3_QTY_THR  string,
VHDR_RVNU_SUM6_QTY_ALL  string,
VHDR_OUTLIER_PYMT  string,
VHDR_TOT_PYMT  string,
VHDR_PPS_PYMT_RTN_CD  string,
VHDR_PAT_DTE_OF_DEATH  string,
VHDR_PLAN_CD_REASSGN_INDC  string,
VHDR_REMK_INDC  string,
VHDR_SPON_DTE_OF_DEATH  string,
VHDR_TNEX_FILING_STATE_CD  string,
VHDR_TNEX_INTRST_LIAB_INDC  string,
VHDR_TNEX_PAT_FIRST_NAME  string,
VHDR_TNEX_PAT_MID_NAME  string,
VHDR_TNEX_PAT_LAST_NAME  string,
VHDR_TNEX_PAT_GENERATION  string,
VHDR_TNEX_SPON_FIRST_NAME  string,
VHDR_TNEX_SPON_MID_NAME  string,
VHDR_TNEX_SPON_LAST_NAME  string,
VHDR_TNEX_SPON_GENERATION  string,
VHDR_TRTMT_AUTH_CD  string,
VHDR_COST_SHARE_AMT  string,
VHDR_STLMT_CK_DTE  string,
VHDR_ADMIN_CLIN_X_F  string,
VHDR_ADMIN_CLIN_1  string,
VHDR_ADMIN_CLIN_2  string,
VHDR_ADMIN_CLIN_3  string,
VHDR_ACRS_CK_SRC_CD  string,
VHDR_SR_PRIME_DAILY_RATE  string,
VHDR_SR_PRIME_ANNUAL_RATE  string,
VHDR_SR_PRIME_INTEREST_DAYS  string,
VHDR_SR_PRIME_INTEREST_AMOU  string,
VHDR_ACTN_RQST_NO  string,
VHDR_ADJUSTMENT_INDC  string,
VHDR_AMT_PAID_BASIC  string,
VHDR_APPROVED_AMT  string,
VHDR_BASIC_COV_TO  string,
VHDR_BASIC_EFF_DATE  string,
VHDR_BP_END_DATE  string,
VHDR_CHAP_OVRR_OCC_INDC  string,
VHDR_CHAP_SPON_SEX  string,
VHDR_CK_NO  string,
VHDR_CLAIM_TYPE  string,
VHDR_CLM_AGE  string,
VHDR_CLM_DISP_IND  string,
VHDR_CLM_OFFSET_AMT  string,
VHDR_CLM_PROC_TYP  string,
VHDR_CLM_TYP_CD  string,
VHDR_COB_INDC  string,
VHDR_COME_UP_INDC  string,
VHDR_CRTF_CODE  string,
VHDR_CYCLE_DATE  string,
VHDR_CYL_RPT_LNE_NO  string,
VHDR_DAYS_LAST_DISP  string,
VHDR_DEFERRED_CTR  string,
VHDR_DEF_RSN_CAT_CD  string,
VHDR_DELAY_IND  string,
VHDR_DENIED_CTR  string,
VHDR_DENTAL_CLM_CTR  string,
VHDR_EMC_CTR  string,
VHDR_EMC_WAIVER  string,
VHDR_EMC_WAIVER_IND  string,
VHDR_EMC_WAIVER_RSN  string,
VHDR_EOB_INDC  string,
VHDR_FAM_DED_TO_TD  string,
VHDR_HARD_COPY_CTR  string,
VHDR_MEDC_PVDR_NO  string,
VHDR_MEDC_SUPPL_NON_PYMT_AMT  string,
VHDR_MEDIA  string,
VHDR_MRTL_STAT  string,
VHDR_NR_COST_SHARE  string,
VHDR_NR_DEDUCTIBLE  string,
VHDR_NR_OTHER_CARRIER_PYMT  string,
VHDR_ORIG_CLM_AMT  string,
VHDR_OTHER_CARR_AMT_BASIC  string,
VHDR_OTHER_COORD_LIAB_AMT  string,
VHDR_PAT_CNTL_NO_1  string,
VHDR_PAT_DED_TO_TD  string,
VHDR_PAT_SEX  string,
VHDR_PD_CTR  string,
VHDR_PERSON_ASSOC_BGN_DTE  string,
VHDR_PERSON_ASSOC_CODE  string,
VHDR_PERSON_ASSOC_END_DTE  string,
VHDR_PERSON_ASSOC_END_REAS  string,
VHDR_POS_CTR  string,
VHDR_PVDR_NO_X  string,
VHDR_PVDR_NO_1  string,
VHDR_PVDR_NO_2  string,
VHDR_PVDR_NO_3  string,
VHDR_PVDR_NO_4  string,
VHDR_PVDR_NO_5  string,
VHDR_REGULAR_OR_ADJ_CLM  string,
VHDR_RESOLVED_CTR  string,
VHDR_RESOLVED_CYCLE_DT  string,
VHDR_RES_SHR_PGM_NO  string,
VHDR_ROUTING_CODE  string,
VHDR_RPT_RET_EXCL  string,
VHDR_RSLVD_DATE  string,
VHDR_SPCL_PROCS_CD_2  string,
VHDR_SPLIT_CLAIM_INDC  string,
VHDR_SRVC_ST  string,
VHDR_SS09_DEF_CODE  string,
VHDR_STL_CTR  string,
VHDR_SUB_ADDR_CHANGE_INDC  string,
VHDR_SUB_OTH_INFO_SECT  string,
VHDR_SUB_DOB  string,
VHDR_SUB_SEX  string,
VHDR_SUB_MRTL_STAT  string,
VHDR_SUB_ID_NO  string,
VHDR_SUB_WORK_LOC  string,
VHDR_SUB_LOCAL_NO  string,
VHDR_OTHER_CARR_POL_NO  string,
VHDR_SYSTEM_IND  string,
VHDR_TRIGGER_INDC  string,
VHDR_TRTMT_AUTH_NO  string,
VHDR_INCAP_INDC  string,
VHDR_XFR_CTR  string,
VHDR_APC_DISC_FRACTION  string,
VHDR_APC_FIXED_DOLLAR_THRES  string,
VHDR_APC_LABOR_SHARE  string,
VHDR_APC_OUTLIER_FACTOR  string,
VHDR_APC_RETURN_CODE  string,
VHDR_APC_TERM_PROC_DISC  string,
VHDR_APC_THRESH_MULTIPLIER  string,
VHDR_APC_TOTAL_PAYMENT  string,
VHDR_PPS_COST_TO_CHG_TYPE  string,
VHDR_RURAL_DIFF_FACTOR  string,
VHDR_OPPS_PROCESS_INDC  string,
VHDR_APC_CLM_DEN_REAS_INF_X  string,
VHDR_APC_CLM_DEN_REAS_1  string,
VHDR_APC_CLM_DEN_REAS_2  string,
VHDR_APC_CLM_DEN_REAS_3  string,
VHDR_APC_CLM_DEN_REAS_4  string,
VHDR_APC_CLM_DEN_REAS_5  string,
VHDR_APC_CLM_DEN_REAS_6  string,
VHDR_APC_CLM_DEN_REAS_7  string,
VHDR_APC_CLM_DEN_REAS_8  string,
VHDR_APC_CLM_DEN_REAS_9  string,
VHDR_APC_CLM_DEN_REAS_10  string,
VHDR_APC_CLM_DEN_REAS_11  string,
VHDR_APC_CLM_DEN_REAS_12  string,
VHDR_APC_CLM_DEN_REAS_13  string,
VHDR_APC_CLM_DEN_REAS_14  string,
VHDR_APC_CLM_DEN_REAS_15  string,
VHDR_APC_CLM_DISP  string,
VHDR_APC_CLM_LINE_DENIAL_DIS  string,
VHDR_APC_CLM_MED_SUSP_DISP  string,
VHDR_APC_CLM_VALID_SUSP_DISP  string,
VHDR_APC_DENIAL_DISP  string,
VHDR_APC_LINE_DENIAL_REAS_X  string,
VHDR_APC_LINE_DENIAL_REAS_1  string,
VHDR_APC_LINE_DENIAL_REAS_2  string,
VHDR_APC_LINE_DENIAL_REAS_3  string,
VHDR_APC_LINE_DENIAL_REAS_4  string,
VHDR_APC_LINE_DENIAL_REAS_5  string,
VHDR_APC_LINE_DENIAL_REAS_6  string,
VHDR_APC_LINE_DENIAL_REAS_7  string,
VHDR_APC_LINE_DENIAL_REAS_8  string,
VHDR_APC_LINE_DENIAL_REAS_9  string,
VHDR_APC_LINE_DENIAL_REAS_10  string,
VHDR_APC_LINE_DENIAL_REAS_11  string,
VHDR_APC_LINE_DENIAL_REAS_12  string,
VHDR_APC_LINE_DENIAL_REAS_13  string,
VHDR_APC_LINE_DENIAL_REAS_14  string,
VHDR_APC_LINE_DENIAL_REAS_15  string,
VHDR_APC_LINE_DENIAL_REAS_16  string,
VHDR_APC_LINE_DENIAL_REAS_17  string,
VHDR_APC_LINE_DENIAL_REAS_18  string,
VHDR_APC_LINE_DENIAL_REAS_19  string,
VHDR_APC_LINE_DENIAL_REAS_20  string,
VHDR_APC_LINE_DENIAL_REAS_21  string,
VHDR_APC_LINE_DENIAL_REAS_22  string,
VHDR_APC_LINE_DENIAL_REAS_23  string,
VHDR_APC_LINE_DENIAL_REAS_24  string,
VHDR_APC_LINE_DENIAL_REAS_25  string,
VHDR_APC_LINE_DENIAL_REAS_26  string,
VHDR_APC_LINE_DENIAL_REAS_27  string,
VHDR_APC_LINE_DENIAL_REAS_28  string,
VHDR_APC_LINE_DENIAL_REAS_29  string,
VHDR_APC_LINE_DENIAL_REAS_30  string,
VHDR_APC_MED_SUSP_REAS_X  string,
VHDR_APC_MED_SUSP_REAS_1  string,
VHDR_APC_MED_SUSP_REAS_2  string,
VHDR_APC_MED_SUSP_REAS_3  string,
VHDR_APC_MED_SUSP_REAS_4  string,
VHDR_APC_MED_SUSP_REAS_5  string,
VHDR_APC_RETURN_BUFF_FLAG  string,
VHDR_APC_VALID_SUSP_REAS_X  string,
VHDR_APC_VALID_SUSP_REAS  string,
VHDR_CORRSP_DCN  string,
VHDR_CORRSP_DATE  string,
VHDR_CORRSP_SRC  string,
VHDR_CORRSP_SEQ  string,
VHDR_OCE_RETURN_CD  string,
VHDR_REAS_VISIT_DIAG_X  string,
VHDR_REAS_VISIT_DIAG_1  string,
VHDR_REAS_VISIT_DIAG_2  string,
VHDR_REAS_VISIT_DIAG_3  string,
VHDR_PAT_ADDR1_EXT  string,
VHDR_PAT_ADDR2_EXT  string,
VHDR_PAT_CITY_EXT  string,
VHDR_PAT_CNTRY  string,
VHDR_UB_PATIENT_ID  string,
VHDR_MEDICAID_PVDR_ID  string,
VHDR_ICN_DCN_NO  string,
VHDR_QM_AUDIT_SCRIPT  string,
VHDR_ORIG_RECEIPT_DATE  string,
VHDR_PAYTO_PVDR_TAX_ID  string,
VHDR_SUBMIT_PVDR_TAXONOMY  string,
VHDR_SUBMIT_PVDR_ID  string,
VHDR_BILL_PVDR_NPI_NO  string,
VHDR_BILL_PVDR_NPI  string,
VHDR_FILLER_01  string,
VHDR_PCM_PVDR_NPI_NO  string,
VHDR_PCM_PVDR_NPI  string,
VHDR_FILLER_02  string,
VHDR_ATYPICAL_PVDR_IND  string,
VHDR_PVDR_FLIP_IND  string,
VHDR_SVC_PVDR_NAME  string,
VHDR_SVC_PVDR_ADDR1  string,
VHDR_SVC_PVDR_ADDR2  string,
VHDR_SVC_PVDR_CITY  string,
VHDR_SVC_PVDR_STATE  string,
VHDR_SVC_PVDR_ZIP  string,
VHDR_SVC_PVDR_PHONE  string,
VHDR_BILL_PVDR_NAME  string,
VHDR_BILL_PVDR_ADDR1  string,
VHDR_BILL_PVDR_ADDR2  string,
VHDR_BILL_PVDR_CITY  string,
VHDR_BILL_PVDR_STATE  string,
VHDR_BILL_PVDR_ZIP  string,
VHDR_ATTND_PVDR_NPI_NO  string,
VHDR_ATTND_PVDR_NPI  string,
VHDR_FILLER_03  string,
VHDR_ATTND_PVDR_ID_QUAL  string,
VHDR_ATTND_PVDR_ID  string,
VHDR_ATTND_PVDR_LAST_NAME  string,
VHDR_ATTND_PVDR_FST_NAME  string,
VHDR_OPER_PVDR_NPI_NO  string,
VHDR_OPER_PVDR_NPI  string,
VHDR_FILLER_04  string,
VHDR_OPER_PVDR_ID_QUAL  string,
VHDR_OPER_PVDR_ID  string,
VHDR_OPER_PVDR_LAST_NAME  string,
VHDR_OPER_PVDR_FST_NAME  string,
VHDR_OTH1_PVDR_NPI_QUAL  string,
VHDR_OTH1_PVDR_NPI_NO  string,
VHDR_OTH1_PVDR_NPI  string,
VHDR_FILLER_05  string,
VHDR_OTH1_PVDR_ID_QUAL  string,
VHDR_OTH1_PVDR_ID  string,
VHDR_OTH1_PVDR_LAST_NAME  string,
VHDR_OTH1_PVDR_FST_NAME  string,
VHDR_OTH2_PVDR_NPI_QUAL  string,
VHDR_OTH2_PVDR_NPI_NO  string,
VHDR_OTH2_PVDR_NPI  string,
VHDR_FILLER_06  string,
VHDR_OTH2_PVDR_ID_QUAL  string,
VHDR_OTH2_PVDR_ID  string,
VHDR_OTH2_PVDR_LAST_NAME  string,
VHDR_OTH2_PVDR_FST_NAME  string,
VHDR_REFER_PVDR_NPI_NO  string,
VHDR_REFER_PVDR_NPI  string,
VHDR_FILLER_07  string,
VHDR_REFER_PVDR_ID_QUAL  string,
VHDR_EXPND_DIAG_CODE_X  string,
VHDR_EXPND_DIAG_CD_1  string,
VHDR_DIAG_POA_1  string,
VHDR_EXPND_DIAG_CD_2  string,
VHDR_DIAG_POA_2  string,
VHDR_EXPND_DIAG_CD_3  string,
VHDR_DIAG_POA_3  string,
VHDR_EXPND_DIAG_CD_4  string,
VHDR_DIAG_POA_4  string,
VHDR_EXPND_DIAG_CD_5  string,
VHDR_DIAG_POA_5  string,
VHDR_EXPND_DIAG_CD_6  string,
VHDR_DIAG_POA_6  string,
VHDR_EXPND_DIAG_CD_7  string,
VHDR_DIAG_POA_7  string,
VHDR_EXPND_DIAG_CD_8  string,
VHDR_DIAG_POA_8  string,
VHDR_EXPND_DIAG_CD_9  string,
VHDR_DIAG_POA_9  string,
VHDR_EXPND_DIAG_CD_10  string,
VHDR_DIAG_POA_10  string,
VHDR_EXPND_DIAG_CD_11  string,
VHDR_DIAG_POA_11  string,
VHDR_EXPND_DIAG_CD_12  string,
VHDR_DIAG_POA_12  string,
VHDR_EXPND_DIAG_CD_13  string,
VHDR_DIAG_POA_13  string,
VHDR_EXPND_DIAG_CD_14  string,
VHDR_DIAG_POA_14  string,
VHDR_EXPND_DIAG_CD_15  string,
VHDR_DIAG_POA_15  string,
VHDR_EXPND_DIAG_CD_16  string,
VHDR_DIAG_POA_16  string,
VHDR_EXPND_DIAG_CD_17  string,
VHDR_DIAG_POA_17  string,
VHDR_EXPND_DIAG_CD_18  string,
VHDR_DIAG_POA_18  string,
VHDR_EXPND_DIAG_CD_19  string,
VHDR_DIAG_POA_19  string,
VHDR_EXPND_DIAG_CD_20  string,
VHDR_DIAG_POA_20  string,
VHDR_EXPND_DIAG_CD_21  string,
VHDR_DIAG_POA_21  string,
VHDR_EXPND_DIAG_CD_22  string,
VHDR_DIAG_POA_22  string,
VHDR_EXPND_DIAG_CD_23  string,
VHDR_DIAG_POA_23  string,
VHDR_EXPND_DIAG_CD_24  string,
VHDR_DIAG_POA_24  string,
VHDR_EXPND_DIAG_CD_25  string,
VHDR_DIAG_POA_25  string,
VHDR_EXPND_PRINC_DIAG  string,
VHDR_EXPND_PRIC_DIAG_POA  string,
VHDR_ADMIT_DIAG_CODE  string,
VHDR_SURGICAL_PROCEDURES_X  string,
VHDR_PRINC_SURG_PROC_1  string,
VHDR_PRINC_SURG_PROC_DATE_1  string,
VHDR_PRINC_SURG_PROC_2  string,
VHDR_PRINC_SURG_PROC_DATE_2  string,
VHDR_PRINC_SURG_PROC_3  string,
VHDR_PRINC_SURG_PROC_DATE_3  string,
VHDR_PRINC_SURG_PROC_4  string,
VHDR_PRINC_SURG_PROC_DATE_4  string,
VHDR_PRINC_SURG_PROC_5  string,
VHDR_PRINC_SURG_PROC_DATE_5  string,
VHDR_PRINC_SURG_PROC_6  string,
VHDR_PRINC_SURG_PROC_DATE_6  string,
VHDR_PRINC_SURG_PROC_7  string,
VHDR_PRINC_SURG_PROC_DATE_7  string,
VHDR_PRINC_SURG_PROC_8  string,
VHDR_PRINC_SURG_PROC_DATE_8  string,
VHDR_PRINC_SURG_PROC_9  string,
VHDR_PRINC_SURG_PROC_DATE_9  string,
VHDR_PRINC_SURG_PROC_10  string,
VHDR_PRINC_SURG_PROC_DATE_10  string,
VHDR_PRINC_SURG_PROC_11  string,
VHDR_PRINC_SURG_PROC_DATE_11  string,
VHDR_PRINC_SURG_PROC_12  string,
VHDR_PRINC_SURG_PROC_DATE_12  string,
VHDR_PRINC_SURG_PROC_13  string,
VHDR_PRINC_SURG_PROC_DATE_13  string,
VHDR_PRINC_SURG_PROC_14  string,
VHDR_PRINC_SURG_PROC_DATE_14  string,
VHDR_PRINC_SURG_PROC_15  string,
VHDR_PRINC_SURG_PROC_DATE_15  string,
VHDR_PRINC_SURG_PROC_16  string,
VHDR_PRINC_SURG_PROC_DATE_16  string,
VHDR_PRINC_SURG_PROC_17  string,
VHDR_PRINC_SURG_PROC_DATE_17  string,
VHDR_PRINC_SURG_PROC_18  string,
VHDR_PRINC_SURG_PROC_DATE_18  string,
VHDR_PRINC_SURG_PROC_19  string,
VHDR_PRINC_SURG_PROC_DATE_19  string,
VHDR_PRINC_SURG_PROC_20  string,
VHDR_PRINC_SURG_PROC_DATE_20  string,
VHDR_PRINC_SURG_PROC_21  string,
VHDR_PRINC_SURG_PROC_DATE_21  string,
VHDR_PRINC_SURG_PROC_22  string,
VHDR_PRINC_SURG_PROC_DATE_22  string,
VHDR_PRINC_SURG_PROC_23  string,
VHDR_PRINC_SURG_PROC_DATE_23  string,
VHDR_PRINC_SURG_PROC_24  string,
VHDR_PRINC_SURG_PROC_DATE_24  string,
VHDR_PRINC_SURG_PROC_25  string,
VHDR_PRINC_SURG_PROC_DATE_25  string,
VHDR_CAUSE_INJ_DIAG_X  string,
VHDR_CAUSE_INJ_DIAG_CD  string,
VHDR_CAUSE_INJ_DIAG_POA  string,
VHDR_OVRFLW_CODES_X  string,
VHDR_CODE_LIST_QUAL_1  string,
VHDR_CODE_CODE_1  string,
VHDR_CODE_VALUE_1  string,
VHDR_CODE_LIST_QUAL_2  string,
VHDR_CODE_CODE_2  string,
VHDR_CODE_VALUE_2  string,
VHDR_CODE_LIST_QUAL_3  string,
VHDR_CODE_CODE_3  string,
VHDR_CODE_VALUE_3  string,
VHDR_CODE_LIST_QUAL_4  string,
VHDR_CODE_CODE_4  string,
VHDR_CODE_VALUE_4  string,
VHDR_TREATMNT_AUTH  string,
VHDR_EXPND_TYPE_BILL  string,
VHDR_ACCIDENT_STATE  string,
VHDR_EXPND_OCC_SPAN_INFO_X  string,
VHDR_EXPND_OCC_SPAN_CODE_1  string,
VHDR_EXPND_OCC_SPAN_FROM_DT_1  string,
VHDR_EXPND_OCC_SPAN_TO_DT_1  string,
VHDR_EXPND_OCC_SPAN_CODE_2  string,
VHDR_EXPND_OCC_SPAN_FROM_DT_2  string,
VHDR_EXPND_OCC_SPAN_TO_DT_2  string,
VHDR_EXPND_OCC_SPAN_CODE_3  string,
VHDR_EXPND_OCC_SPAN_FROM_DT_3  string,
VHDR_EXPND_OCC_SPAN_TO_DT_3  string,
VHDR_EXPND_OCC_SPAN_CODE_4  string,
VHDR_EXPND_OCC_SPAN_FROM_DT_4  string,
VHDR_EXPND_OCC_SPAN_TO_DT_4  string,
VHDR_EXPND_OCC_CODES_INFO_X  string,
VHDR_EXPND_OCC_CODE_1  string,
VHDR_EXPND_OCC_DATE_1  string,
VHDR_EXPND_OCC_CODE_2  string,
VHDR_EXPND_OCC_DATE_2  string,
VHDR_EXPND_OCC_CODE_3  string,
VHDR_EXPND_OCC_DATE_3  string,
VHDR_EXPND_OCC_CODE_4  string,
VHDR_EXPND_OCC_DATE_4  string,
VHDR_EXPND_OCC_CODE_5  string,
VHDR_EXPND_OCC_DATE_5  string,
VHDR_EXPND_OCC_CODE_6  string,
VHDR_EXPND_OCC_DATE_6  string,
VHDR_EXPND_OCC_CODE_7  string,
VHDR_EXPND_OCC_DATE_7  string,
VHDR_EXPND_OCC_CODE_8  string,
VHDR_EXPND_OCC_DATE_8  string,
VHDR_EXPND_COND_CODES_INFO_X  string,
VHDR_EXPND_COND_CODE_1  string,
VHDR_EXPND_COND_CODE_2  string,
VHDR_EXPND_COND_CODE_3  string,
VHDR_EXPND_COND_CODE_4  string,
VHDR_EXPND_COND_CODE_5  string,
VHDR_EXPND_COND_CODE_6  string,
VHDR_EXPND_COND_CODE_7  string,
VHDR_EXPND_COND_CODE_8  string,
VHDR_EXPND_COND_CODE_9  string,
VHDR_EXPND_COND_CODE_10  string,
VHDR_EXPND_COND_CODE_11  string,
VHDR_NPI_VALIDITY_INDC  string,
VHDR_NPI_BILL_PVDR_SOURCE_IN  string,
VHDR_SUPPL_INFO_INDC  string,
VHDR_PPS_GRPR_CODE  string,
VHDR_BYP_TIME_FILE_INDC  string,
VHDR_APC_VERSION_CD  string,
VHDR_PVDR_SCREEN_SEL  string,
VHDR_SUBMIT_NPI_NO  string,
VHDR_SUBMIT_NPI  string,
VHDR_FILLER_08  string,
VHDR_NPI_MATCH_RTN_CD  string,
VHDR_SUBMIT_PAYTO_PVDR_TAXID  string,
VHDR_LUPA_ADD_ON_PMT  string,
VHDR_POA_LOGIC_EXEMPT_INDC  string,
VHDR_DRG_HAC_ASSGN_CRIT_X  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_1  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_2  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_3  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_4  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_5  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_6  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_7  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_8  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_9  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_10  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_11  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_12  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_13  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_14  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_15  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_16  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_17  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_18  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_19  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_20  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_21  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_22  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_23  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_24  string,
VHDR_DRG_DIAG_HAC_ASSIGM_CRI_25  string,
VHDR_PREV_CLM_BILL_STAT  string,
VHDR_HIPAA_837_VER_INDC  string,
VHDR_CR_ADJ_RFND_REAS  string,
VHDR_TOT_PYMT_AMT_DIFF  string,
VHDR_CONTRACT_INDC  string,
VHDR_PRE_DISC_ALLOW_AMT  string,
VHDR_AMT_NTW_PVDR_DISC  string,
VHDR_ADJ_PRE_DIS_ALLOW_AMT  string,
VHDR_ROOM_BOARD_INDC  string,
VHDR_HCN_SSN_CHNG_INDC  string,
VHDR_ABRTN_COND_CODE  string,
VHDR_ICD_VERSION_INDC  string,
VHDR_POP_ZIP_CODE  string,
VHDR_NUM_PEOPLE_TRANSPORTED  string,
VHDR_HICF_1500_BLK8_DATA  string,
VHDR_HICF_1500_BLK9B_DATA  string,
VHDR_HICF_1500_BLK9C_DATA  string,
VHDR_OTHER_CLM_QUAL  string,
VHDR_OTHER_CLM_INFO  string,
VHDR_CURR_ILL_INJ_LMP_DT  string,
VHDR_CURR_ILL_INJ_LMP_Q  string,
VHDR_OTHER_DATE_QUAL  string,
VHDR_OTHER_DATE  string,
VHDR_ADDTL_CLM_INFO  string,
VHDR_RESUB_CODE  string,
VHDR_ORIG_REF_NUM  string,
VHDR_HICF_1500_BLK30_DATA  string,
VHDR_PAT_PHONE_NO  string,
VHDR_OTH_INS_NAME  string,
VHDR_OTH_INS_FNAME  string,
VHDR_OTH_INS_LNAME  string,
VHDR_OTH_INS_MI  string,
VHDR_OTH_INS_GEN  string,
VHDR_OTH_POL_NO  string,
VHDR_OTH_INS_PLAN  string,
VHDR_INS_DOB  string,
VHDR_UNAB_WK_FROM  string,
VHDR_UNAB_WK_TO  string,
VHDR_HICF_1500_BLK17_QUAL  string,
VHDR_OUTSIDE_LAB  string,
VHDR_LAB_CHARGES  string,
VHDR_EPSDT  string,
VHDR_TAX_ID_IND  string,
VHDR_PROV_SIGN  string,
VHDR_SVC_PVDR_NPI  string,
VHDR_SVC_PVDR_NO  string,
VHDR_INS_GRP_NO  string,
VHDR_INS_GRP_NAME  string,
VHDR_REFER_PVDR_ID  string,
VHDR_ATTND_PVDR_SPEC  string,
VHDR_ATTND_PVDR_SYST_IND  string,
VHDR_OPER_PVDR_SPEC  string,
VHDR_OPER_PVDR_SYST_IND  string,
VHDR_OTH1_PVDR_SPEC  string,
VHDR_OTH1_PVDR_SYST_IND  string,
VHDR_OTH2_PVDR_SPEC  string,
VHDR_OTH2_PVDR_SYST_IND  string,
VHDR_FX_MOD_ADJ  string,
VHDR_PREPAY_AUDIT_INDC  string,
VHDR_CY_SECT_X  string,
VHDR_CY_INDC_1  string,
VHDR_CY_FAM_DED_OUTNTWK_TO_1  string,
VHDR_CY_PAT_DED_OUTNTWK_TO_1  string,
VHDR_CY_DED_OUTNTWK_AMT_1  string,
VHDR_CY_INDC_2  string,
VHDR_CY_FAM_DED_OUTNTWK_TO_2  string,
VHDR_CY_PAT_DED_OUTNTWK_TO_2  string,
VHDR_CY_DED_OUTNTWK_AMT_2  string,
VHDR_CY_INDC_3  string,
VHDR_CY_FAM_DED_OUTNTWK_TO_3  string,
VHDR_CY_PAT_DED_OUTNTWK_TO_3  string,
VHDR_CY_DED_OUTNTWK_AMT_3  string,
VHDR_CY_INDC_4  string,
VHDR_CY_FAM_DED_OUTNTWK_TO_4  string,
VHDR_CY_PAT_DED_OUTNTWK_TO_4  string,
VHDR_CY_DED_OUTNTWK_AMT_4  string,
VHDR_CY_INDC_5  string,
VHDR_CY_FAM_DED_OUTNTWK_TO_5  string,
VHDR_CY_PAT_DED_OUTNTWK_TO_5  string,
VHDR_CY_DED_OUTNTWK_AMT_5  string,
VHDR_CY_INDC_6  string,
VHDR_CY_FAM_DED_OUTNTWK_TO_6  string,
VHDR_CY_PAT_DED_OUTNTWK_TO_6  string,
VHDR_CY_DED_OUTNTWK_AMT_6  string,
VHDR_VA_ELIGIBLE_INDC  string,
VHDR_VA_BAD_ADDR_INDC  string,
VHDR_PX_TOT_CHRG_AMT  string,
VHDR_PX_CLM_AMT_PAID_BENE  string,
VHDR_PX_PAID_BY_SBSCR  string,
VHDR_PX_CLM_AMT_PAID_PROV  string,
VHDR_PX_PAT_LIAB_AMT  string,
VHDR_PX_NO_PYMT_RED_DAY_SRVC  string,
VHDR_PX_AMT_MAJ_MED  string,
VHDR_PX_OTHR_HLTH_INS_ALOW_AMT  string,
VHDR_PX_PYMT_RED_AMT  string,
VHDR_PX_TPL_AMT  string,
VHDR_PX_ADM_DATE  string,
VHDR_PX_BP_END_DATE  string,
VHDR_PX_BP_START_DATE  string,
VHDR_PX_CHAP_OVRR_OCC_INDC  string,
VHDR_PX_CONTRACT_KEY_CUR  string,
VHDR_PX_DATE_ADJ_ID  string,
VHDR_PX_DISCHARGE_DATE  string,
VHDR_PX_ENROL_CODE  string,
VHDR_PX_GRP_NO_CUR  string,
VHDR_PX_NBR_LINES  string,
VHDR_PX_OTHER_CARR_DED_AMT  string,
VHDR_PX_PAT_COV_EFF_DATE  string,
VHDR_PX_PAT_ID  string,
VHDR_PX_SBSCR_NAME  string,
VHDR_PX_SENIOR_PRIME_CLEAN  string,
VHDR_PX_SUB_ADDR_SECT  string,
VHDR_PX_SUB_OTH_INFO_SECT  string,
VHDR_PX_SUCSV_ADM_INDC  string,
VHDR_PX_AMT_NTW_PVDR_DISC  string,
VHDR_PX_ADJ_PRE_DIS_ALLW_AMT  string,
VHDR_CHECK_NUMBER  string,
VHDR_CHNG_REAS  string,
VHDR_DV_PGM_TYPE  string,
VHDR_MICRO_SUSP_DATE  string,
VHDR_RESOLVED_IN_CYCLE  string,
VHDR_VAMOA_DIAG_INDC  string,
VHDR_REGION_INDC  string,
VHDR_VA_ICN_NO  string,
FILLER_09  string,
VHDR_VA_ICN_17  string,
FILLER_10  string,
VHDR_FILLER_END  string
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
from pyspark.sql.types import StructType, StructField, StringType, MapType, TimestampType, FloatType, IntegerType
from pyspark.sql.functions import col, substring
import pandas as pd
import numpy as np
#/*************************************/
#/Specify schema for the header record /
#/*************************************/
claimsDictSchema = StructType([ \
    StructField("Name", StringType(),True), \
    StructField("Pos", IntegerType(),True), \
    StructField("Type1", StringType(),True), \
    StructField("Len", IntegerType(), True), \
    StructField("DD#", StringType(), True), \
    StructField("Sign", StringType(), True), \
    StructField("Pack", StringType(), True), \
    StructField("Occurs", IntegerType(), True), \
    StructField("ColumnName", StringType(), True)
  ]);
#/******************************************************/
#Specify connection parameters,
#using storage account and hardcoded key value **********
#/******************************************************/
spark.conf.set(
    "fs.azure.account.key.twdasbxusgadatadl.dfs.core.usgovcloudapi.net",
"+/Au+YDSjr0+JtubIDDkqlXTx29fjC70g3HhhKRpEOsTIsMKuqebYmNS2PRaJgbLgnF/q2rhYWyg+AStXfziSg==")
spark.conf.set("spark.databricks.delta.replaceWhere.constraintCheck.enabled", False)

#/******************************************************/
#/Read Schema file                                     */ 
#/Schema file created with headers                     */
#/******************************************************/
ClaimsDictDF = spark.read.option("header",True).csv("abfss://tirf@twdasbxusgadatadl.dfs.core.usgovcloudapi.net/dictionaries/pgba-claims_header_record_01.csv", claimsDictSchema)
ClaimsDictDF.display()
#/******************************************************/
#read Data file                                        */
#/******************************************************/
ClaimsDataDF = spark.read.option("inferSchema",True).text("abfss://tirf@twdasbxusgadatadl.dfs.core.usgovcloudapi.net/claims/DEFERRED_CLAIMS_PGBA_REG4_01_20230321.TXT")

#/******************************************************/
#use map and collect to create dict dataframe          */
#/******************************************************/

sfDict = map(lambda x: x.asDict(), ClaimsDictDF.collect())
#print(sfDict)

#/******************************************************/
#use .select and substring to parse                    */
#data treated as string                                */
#/******************************************************/

newdf= ClaimsDataDF.select( 
                   [ 
                    (substring(str='value',pos=int(row['Pos']),len=int(row['Len'])) ) .alias(row['ColumnName']) 
                    for row in sfDict
                    ]
)
#/******************************************************/
#write dataframe to the table created befOre           */
#/******************************************************/

newdf.write.format("delta") \
          .mode("overwrite") \
          .option("overwriteSchema", "true") \
         . saveAsTable("claims_raw_R01")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
